# %% [markdown]
# <a href="https://colab.research.google.com/github/edsson12/clase1/blob/master/clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# Ingreso
a= -5 # rango de tiempo
b= 5
dt = 0.1
sigma =0 #s=0+0j
omega =0

# PROCEDIMIENTO
t= np.arange(a,b,dt) #creando un vector 
s= complex(sigma,omega)# creando un numero complejo
senal=np.exp(s*t)#señal exponencial sacada de numpy

#SLAIDA-grafica
plt.figure(1)
plt.plot(t, np.real(senal), label='real') # se plotea la parte real de la señal "senal" con un label
plt.plot(t,np.imag(senal),label='imaginaria') # se plotea la parte imaginaria de la señal "senal" con un label

#labels
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()#show para que funcione

# %%
# Ingreso
a= -5 # rango de tiempo
b= 5
dt = 0.1
sigma =0 #s=0+0j
omega =1

# PROCEDIMIENTO
t= np.arange(a,b,dt) #creando un vector 
s= complex(sigma,omega)# creando un numero complejo
senal=np.exp(s*t)#señal exponencial sacada de numpy

#SLAIDA-grafica
plt.figure(1)
plt.plot(t, np.real(senal), label='real') # se plotea la parte real de la señal "senal" con un label
plt.plot(t,np.imag(senal),label='imaginaria') # se plotea la parte imaginaria de la señal "senal" con un label

#labels
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()#show para que funcione

# %%
# un sinusiode o=0, w>0
sigma = 0
omega = 1

s = complex(sigma,omega)
señal = np.exp(s*t)

#SALIDA - gráfica
plt.figure(4)
plt.plot(np.real(senal),np.imag(senal),label='complejo')
plt.xlabel('real')
plt.ylabel('imaginario')0
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()#show para que funcione

# %%
import scipy.integrate as integrate
#INGRESO

W=1
a=0.1
b=0
c=4*2*np.pi # periodo
dte= 0.005

#procedimiento
te=np.arange(b,c,dte)
xe=np.exp(-a*te)

# energia en un periodo
cuadradoxe=xe**2
energiaxe= integrate.simps(cuadradoxe,te)

#SALIDA
print('la energia de xe es:',energiaxe)


#grafica
plt.plot(te,xe,label='xe')
plt.fill_between(te,0,cuadradoxe,color='lightgreen')
plt.plot(te,cuadradoxe,'g--', label='xe^2')
plt.xlabel('t')
plt.legend()
plt.show()

# %%
import scipy.integrate as integrate
#ingreso 

w=1
a=0
b= 2*np.pi #un periodo
dte=0.005
Q=0
A=2

# procedimiento
T=2*np.pi/w
te=np.arange(a,b,dte)
xe=A*np.cos(w*te+Q)

#energia en un periodo
cuadradoxe=xe**2
energiaxe= integrate.simps(cuadradoxe,te)

#potencia en un periodo
potenciaxe=(1/T)*energiaxe

#salida

print('la potencia de xr es: ', potenciaxe)
#grafica
plt.plot(te,xe,label='xe')
plt.fill_between(te,0,cuadradoxe,color='lightgreen')
plt.plot(te,cuadradoxe,'g--', label='xe^2')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# la potencia de xr es:  1.9979721773265833
